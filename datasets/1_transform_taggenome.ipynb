# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !wget https://files.grouplens.org/datasets/tag-genome-2021/genome_2021.zip
# !unzip genome_2021.zip
# Out:
# --2024-07-09 12:30:56--  https://files.grouplens.org/datasets/tag-genome-2021/genome_2021.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1928028583 (1.8G) [application/zip]
# Saving to: ‘genome_2021.zip’
#
# genome_2021.zip     100%[===================>]   1.79G  93.9MB/s    in 20s
#
# 2024-07-09 12:31:17 (91.4 MB/s) - ‘genome_2021.zip’ saved [1928028583/1928028583]
#
# Archive:  genome_2021.zip
#    creating: movie_dataset_public_final/
#   inflating: movie_dataset_public_final/.DS_Store
#   inflating: __MACOSX/movie_dataset_public_final/._.DS_Store
#    creating: movie_dataset_public_final/scores/
#   inflating: movie_dataset_public_final/readme.txt
#   inflating: __MACOSX/movie_dataset_public_final/._readme.txt
#    creating: movie_dataset_public_final/processed/
#    creating: movie_dataset_public_final/raw/
#   inflating: __MACOSX/movie_dataset_public_final/._raw
#    creating: movie_dataset_public_final/predictions/
#   inflating: movie_dataset_public_final/scores/glmer.csv
#   inflating: movie_dataset_public_final/scores/tagdl.csv
#   inflating: movie_dataset_public_final/scores/.DS_Store
#   inflating: __MACOSX/movie_dataset_public_final/scores/._.DS_Store
#   inflating: movie_dataset_public_final/processed/.DS_Store
#   inflating: __MACOSX/movie_dataset_public_final/processed/._.DS_Store
#    creating: movie_dataset_public_final/processed/10folds/
#   inflating: movie_dataset_public_final/processed/features_r.csv
#   inflating: __MACOSX/movie_dataset_public_final/processed/._features_r.csv
#   inflating: movie_dataset_public_final/raw/reviews.json
#   inflating: movie_dataset_public_final/raw/.DS_Store
#   inflating: __MACOSX/movie_dataset_public_final/raw/._.DS_Store
#   inflating: movie_dataset_public_final/raw/survey_answers.json
#   inflating: movie_dataset_public_final/raw/metadata.json
#   inflating: movie_dataset_public_final/raw/metadata_updated.json
#   inflating: movie_dataset_public_final/raw/ratings.json
#   inflating: movie_dataset_public_final/raw/tags.json
#   inflating: movie_dataset_public_final/raw/tag_count.json
#   inflating: movie_dataset_public_final/predictions/.DS_Store
#   inflating: __MACOSX/movie_dataset_public_final/predictions/._.DS_Store
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_0.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_5.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_4.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_1.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_3.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_6.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_7.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_2.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_6.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_3.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_2.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_7.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_5.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_0.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_1.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_4.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_9.txt
#   inflating: movie_dataset_public_final/predictions/glmer_predictions_fold_8.txt
#   inflating: movie_dataset_public_final/predictions/performance_results_tenfolds.txt
#   inflating: __MACOSX/movie_dataset_public_final/predictions/._performance_results_tenfolds.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_9.txt
#   inflating: movie_dataset_public_final/predictions/tagdl_predictions_fold_8.txt
#   inflating: movie_dataset_public_final/processed/10folds/.DS_Store
#   inflating: __MACOSX/movie_dataset_public_final/processed/10folds/._.DS_Store
#   inflating: movie_dataset_public_final/processed/10folds/train6.csv
#   inflating: movie_dataset_public_final/processed/10folds/train7.csv
#   inflating: movie_dataset_public_final/processed/10folds/train5.csv
#   inflating: movie_dataset_public_final/processed/10folds/train4.csv
#   inflating: movie_dataset_public_final/processed/10folds/train0.csv
#   inflating: movie_dataset_public_final/processed/10folds/train1.csv
#   inflating: movie_dataset_public_final/processed/10folds/train3.csv
#   inflating: movie_dataset_public_final/processed/10folds/test8.csv
#   inflating: movie_dataset_public_final/processed/10folds/test9.csv
#   inflating: movie_dataset_public_final/processed/10folds/train2.csv
#   inflating: movie_dataset_public_final/processed/10folds/test4.csv
#   inflating: movie_dataset_public_final/processed/10folds/test5.csv
#   inflating: movie_dataset_public_final/processed/10folds/test7.csv
#   inflating: movie_dataset_public_final/processed/10folds/test6.csv
#   inflating: movie_dataset_public_final/processed/10folds/train9.csv
#   inflating: movie_dataset_public_final/processed/10folds/test2.csv
#   inflating: movie_dataset_public_final/processed/10folds/test3.csv
#   inflating: movie_dataset_public_final/processed/10folds/train8.csv
#   inflating: movie_dataset_public_final/processed/10folds/test1.csv
#   inflating: movie_dataset_public_final/processed/10folds/test0.csv

# %%
origin_folder = "./movie_dataset_public_final/raw"
target_folder = "./drive/MyDrive/bc/taggenome"

# %%
# movies.json sample:
# {"title": "Toy Story (1995)", "directedBy": "John Lasseter", "starring": "Tim Allen, Tom Hanks, Don Rickles, Jim Varney, John Ratzenberger, Wallace Shawn, Laurie Metcalf, John Morris, R. Lee Ermey, Annie Potts", "avgRating": 3.89146, "imdbId": "0114709", "item_id": 1}
movies = pd.read_json(f"{origin_folder}/metadata_updated.json", lines=True)
print(movies.shape)
movies.head()
# Out:
# (84661, 6)
#                                 title       directedBy  \
# 0                    Toy Story (1995)    John Lasseter
# 1                      Jumanji (1995)     Joe Johnston
# 2             Grumpier Old Men (1995)    Howard Deutch
# 3            Waiting to Exhale (1995)  Forest Whitaker
# 4  Father of the Bride Part II (1995)    Charles Shyer
#
#                                             starring  avgRating  imdbId  \
# 0  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...    3.89146  114709
# 1  Jonathan Hyde, Bradley Pierce, Robin Williams,...    3.26605  113497
# 2  Jack Lemmon, Walter Matthau, Ann-Margret , Sop...    3.17146  113228
# 3  Angela Bassett, Loretta Devine, Whitney Housto...    2.86824  114885
# 4  Steve Martin, Martin Short, Diane Keaton, Kimb...    3.07620  113041
#
#    item_id
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
# ratings.json sample:
# {"item_id": 5, "user_id": 997206, "rating": 3.0}
ratings = pd.read_json(f"{origin_folder}/ratings.json", lines=True)
print(f'Unique users: {ratings.user_id.nunique()}\nUnique items: {ratings.item_id.nunique()}')
ratings.shape
# Out:
# Unique users: 247383
# Unique items: 67873
# (28490116, 3)

# %%
# Several rows in ratings are duplicates
ratings = ratings.drop_duplicates(subset=['user_id', 'item_id'])
print(f'Unique users: {ratings.user_id.nunique()}\nUnique items: {ratings.item_id.nunique()}')
ratings.shape
# Out:
# Unique users: 247383
# Unique items: 67873
# (28249191, 3)

# %%
# tag_count.json sample:
# {"item_id": 1, "tag_id": 86963, "num": 4}
tag_count = pd.read_json(f"{origin_folder}/tag_count.json", lines=True)
tag_count.shape
# Out:
# (212704, 3)

# %%
def extract_year_from_title(movies, ratings):
    """ Extracts the realease year from title and creates a new column containing the year. Removes movies that do not have release year available from movies and ratings """
    movies["title"] = movies["title"].str.strip()
    movies["year"] = movies["title"].str.extract(r"\((\d{4})\)$")
    movies = movies.dropna(subset=["year"])
    movies["year"] = movies["year"].astype(int)
    movies = movies[["title", "year", "directedBy", "starring", "avgRating", "imdbId", "item_id"]]
    ratings = ratings[ratings["item_id"].isin(movies["item_id"])]

    return movies, ratings

# Call the function
movies, ratings = extract_year_from_title(movies, ratings)
print(f'Movies: {movies.shape}')
print(f'Ratings: {ratings.shape}')
movies.head()
# Out:
# <ipython-input-9-60582691d765>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["year"] = movies["year"].astype(int)
# Movies: (83992, 7)
# Ratings: (28201816, 3)
#                                 title  year       directedBy  \
# 0                    Toy Story (1995)  1995    John Lasseter
# 1                      Jumanji (1995)  1995     Joe Johnston
# 2             Grumpier Old Men (1995)  1995    Howard Deutch
# 3            Waiting to Exhale (1995)  1995  Forest Whitaker
# 4  Father of the Bride Part II (1995)  1995    Charles Shyer
#
#                                             starring  avgRating  imdbId  \
# 0  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...    3.89146  114709
# 1  Jonathan Hyde, Bradley Pierce, Robin Williams,...    3.26605  113497
# 2  Jack Lemmon, Walter Matthau, Ann-Margret , Sop...    3.17146  113228
# 3  Angela Bassett, Loretta Devine, Whitney Housto...    2.86824  114885
# 4  Steve Martin, Martin Short, Diane Keaton, Kimb...    3.07620  113041
#
#    item_id
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
def get_active_users(movies_df, ratings_df, min_year):
    """ Returns a list of user_ids that have rated movies from min_year """

    item_ids = movies_df[movies_df["year"] >= min_year]["item_id"]
    user_ids = ratings_df[ratings_df["item_id"].isin(item_ids)]["user_id"].unique()
    return user_ids

def filter_active_users(movies_df, ratings_df, tag_count_df, min_year):
    """ Filters out all users who haven't rated movies from at least min_year
    Returns a new DataFrame with only ratings from active users and removes movies aren't rated anymore """

    user_ids = get_active_users(movies_df, ratings_df, min_year)
    ratings_df = ratings_df[ratings_df["user_id"].isin(user_ids)]

    # Remove movies that are not rated by any active users
    item_ids = ratings_df["item_id"].unique()
    movies_df = movies_df[movies_df["item_id"].isin(item_ids)]

    # Remove tags that are not related to any active users
    tag_count_df = tag_count_df[tag_count_df["item_id"].isin(item_ids)]

    return ratings_df, movies_df, tag_count_df

ratings, movies, tag_count = filter_active_users(movies, ratings, tag_count, min_year=2015)
print(f'Movies: {movies.shape}')
print(f'Ratings: {ratings.shape}')
print(f'Unique users: {ratings.user_id.nunique()}\nUnique items: {ratings.item_id.nunique()}')
# Out:
# Movies: (66325, 7)
# Ratings: (10076619, 3)
# Unique users: 43380
# Unique items: 66325

# %%
def remove_unpopular_items(ratings_df, movies_df, min_ratings):
    """ Removes unpopular movies with fewer than min_ratings. """
    ratings_per_item = ratings_df.groupby("item_id").size()
    items_to_keep = ratings_per_item[ratings_per_item >= min_ratings].index
    ratings_df = ratings_df[ratings_df["item_id"].isin(items_to_keep)]
    movies_df = movies_df[movies_df["item_id"].isin(items_to_keep)]
    return ratings_df, movies_df

ratings, movies = remove_unpopular_items(ratings, movies, min_ratings=20)
print(f'Movies: {movies.shape}')
print(f'Ratings: {ratings.shape}')
print(f'Unique users: {ratings.user_id.nunique()}\nUnique items: {ratings.item_id.nunique()}')
# Out:
# Movies: (17807, 7)
# Ratings: (9853772, 3)
# Unique users: 43368
# Unique items: 17807

# %%
import numpy as np

# Take 1000 users for testing. The users must have rated at least 25 ratings
user_counts = ratings['user_id'].value_counts()
users_with_100_plus = user_counts[user_counts >= 25].index

selected_users = np.random.choice(users_with_100_plus, size=1000, replace=False)

ratings_test = ratings[ratings['user_id'].isin(selected_users)]

ratings_train = ratings[~ratings['user_id'].isin(selected_users)]

# You now have ratings_train and ratings_test as required
print("Training set size:", ratings_train.shape)
print("Testing set size:", ratings_test.shape)
print(f'Train - unique users: {ratings_train.user_id.nunique()}\nUnique items: {ratings_train.item_id.nunique()}')
print(f'Test - unique users: {ratings_test.user_id.nunique()}\nUnique items: {ratings_test.item_id.nunique()}')
# Out:
# Training set size: (9573225, 3)
# Testing set size: (280547, 3)
# Train - unique users: 42368
# Unique items: 17807
# Test - unique users: 1000
# Unique items: 14504

# %%
train_contains_all_movies = ratings_train.item_id.nunique() == ratings.item_id.nunique()
assert train_contains_all_movies

# %%
no_users_in_common = set(ratings_train.user_id.unique()).isdisjoint(set(ratings_test.user_id.unique()))
assert no_users_in_common

# %%
for i, row in movies.iterrows():
    """ Converts IMDB id to proper format - "tt", followed by a sequence of at least 7 digits long, padded with zeros if necessary
    Secondly, movies starting with "The", "A", "An" have the articles at the end of the title, so we move them back to the beginning
    e.g. "Matrix, The" -> "The Matrix" """
    imdb_id = f'tt{str(row["imdbId"]).zfill(7)}'
    movies.at[i, "imdbId"] = imdb_id


    title = row["title"][:-7]
    year = row["title"][-6:]

    if title.endswith(", The"):
        title = "The " + title[:-5]
    elif title.endswith(", A"):
        title = "A " + title[:-3]
    elif title.endswith(", An"):
        title = "An " + title[:-4]

    movies.at[i, "title"] = title + " " + year

movies.head()
# Out:
#                                 title  year       directedBy  \
# 0                    Toy Story (1995)  1995    John Lasseter
# 1                      Jumanji (1995)  1995     Joe Johnston
# 2             Grumpier Old Men (1995)  1995    Howard Deutch
# 3            Waiting to Exhale (1995)  1995  Forest Whitaker
# 4  Father of the Bride Part II (1995)  1995    Charles Shyer
#
#                                             starring  avgRating     imdbId  \
# 0  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...    3.89146  tt0114709
# 1  Jonathan Hyde, Bradley Pierce, Robin Williams,...    3.26605  tt0113497
# 2  Jack Lemmon, Walter Matthau, Ann-Margret , Sop...    3.17146  tt0113228
# 3  Angela Bassett, Loretta Devine, Whitney Housto...    2.86824  tt0114885
# 4  Steve Martin, Martin Short, Diane Keaton, Kimb...    3.07620  tt0113041
#
#    item_id
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
# Add popularity column to movies based on the number of ratings
ratings_count = ratings_train.groupby('item_id').size().reset_index(name='popularity')
movies_with_popularity = pd.merge(movies, ratings_count, on="item_id")
movies_sorted = movies_with_popularity.sort_values(by='popularity', ascending=False)
movies_sorted = movies_sorted[['title', 'year', 'popularity', 'directedBy', 'starring', 'avgRating', 'imdbId', 'item_id']]

movies_sorted.head()
# Out:
#                                                    title  year  popularity  \
# 2117                                   The Matrix (1999)  1999       28693
# 288                      The Shawshank Redemption (1994)  1994       27201
# 10961                                   Inception (2010)  2010       26153
# 325                                  Forrest Gump (1994)  1994       24417
# 5856   The Lord of the Rings: The Return of the King ...  2003       23997
#
#                             directedBy  \
# 2117   Andy Wachowski, Larry Wachowski
# 288                     Frank Darabont
# 10961                Christopher Nolan
# 325                    Robert Zemeckis
# 5856                     Peter Jackson
#
#                                                 starring  avgRating  \
# 2117   Laurence Fishburne, Keanu Reeves, Hugo Weaving...    4.15952
# 288    Tim Robbins, Morgan Freeman, Bob Gunton, Willi...    4.41985
# 10961  Leonardo DiCaprio, Ken Watanabe, Joseph Gordon...    4.17404
# 325    Tom Hanks, Gary Sinise, Mykelti Williamson, Ro...    4.06633
# 5856   Sean Astin, Ian McKellen, Viggo Mortensen, Eli...    4.10393
#
#           imdbId  item_id
# 2117   tt0133093     2571
# 288    tt0111161      318
# 10961  tt1375666    79132
# 325    tt0109830      356
# 5856   tt0167260     7153

# %%
ratings_train.to_json(f"{target_folder}/ratings.json", orient="records", lines=True)
ratings_test.to_json(f"{target_folder}/ratings_test.json", orient="records", lines=True)
movies_sorted.to_json(f"{target_folder}/movies.json", orient="records", lines=True)
tag_count.to_json(f"{target_folder}/tag_count.json", orient="records", lines=True)
